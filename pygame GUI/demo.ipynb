# %%
from Scraper import clean_data, game_pics
import game

run_main = gui.run_main()

# %%
clean_data()
# Out:
#         Rk               Player Pos   Tm    MP   FG   FG_P  THRP  THRP_P   FT  \
# 0        1   Mahmoud Abdul-Rauf  PG  SAC  17.1  3.3  0.377   0.2   0.161  0.5
# 1        2    Tariq Abdul-Wahad  SG  SAC  16.3  2.4  0.403   0.1   0.211  1.4
# 2        3  Shareef Abdur-Rahim  SF  VAN  36.0  8.0  0.485   0.3   0.412  6.1
# 4        4       Cory Alexander  PG  SAS  13.5  1.6  0.414   0.5   0.313  0.7
# 5        4       Cory Alexander  PG  DEN  34.7  4.8  0.435   2.0   0.411  2.4
# ...    ...                  ...  ..  ...   ...  ...    ...   ...     ...  ...
# 14568  601       Thaddeus Young  PF  TOR  18.3  2.6  0.465   0.7   0.395  0.5
# 14569  602           Trae Young  PG  ATL  34.9  9.4  0.460   3.1   0.382  6.6
# 14570  603       Omer Yurtseven   C  MIA  12.6  2.3  0.526   0.0   0.091  0.7
# 14571  604          Cody Zeller   C  POR  13.1  1.9  0.567   0.0   0.000  1.4
# 14572  605          Ivica Zubac   C  LAC  24.4  4.1  0.626   0.0     NaN  2.2
#
# ...

# %%
run_main.variables()

# %%
run_main.main()
# Out:
# invalid and retried
# invalid and retried
# invalid and retried
# valid game
